# %%
# Features:
#  - read data from BYB (.wav) file

# %%
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %%
# Crop A One-Dimensional Data Array from the Front

def front_crop(data_array, crop_at):
    # Crop the front of a data array
    # crop_at(int): the index of the last sample to crop from the front of the data array
    # return the cropped array
    if crop_at > len(data_array):
        return "ERROR: crop_at larger than data"
    else:
        return data_array[crop_at+1:]

# %%
# Crop A One-Dimensional Data Array from the Back

def back_crop(data_array, crop_at):
    # Crop the back of a data array
    # crop_at(int): the index of the last sample to crop from the back of the data array
    # return the cropped array
    if crop_at > len(data_array):
        return "ERROR: crop_at larger than data"
    else:
        return data_array[:crop_at]

# %%
sample_rate, raw_data = wavfile.read("BYB_Recording_2022-06-08_20.34.54.wav")

# %%
print(raw_data)
print(sample_rate)
# Out:
# [-69 -68 -67 ... 276 277 279]
# 10000

# %%
len(raw_data)
# Out:
# 298229

# %%
rec_time = len(raw_data) / sample_rate
rec_time
# Out:
# 29.8229

# %%
X = np.linspace(0, rec_time, len(raw_data))
Y = raw_data
plt.plot(X, Y)

# %% [markdown]
# ## Front Crop Example

# %%
cropped_data = front_crop(raw_data, 50000)

# %%
rec_time2 = len(cropped_data) / sample_rate

X2 = np.linspace(rec_time - rec_time2, rec_time, len(cropped_data))
Y2 = cropped_data
plt.plot(X2, Y2)

# %% [markdown]
# ## Back Crop Example

# %%
back_cropped_data = front_crop(raw_data, 50000)

# %%
rec_time3 = len(back_cropped_data) / sample_rate

X3 = np.linspace(rec_time - rec_time3, rec_time, len(back_cropped_data))
Y3 = back_cropped_data
plt.plot(X3, Y3)
